# %%
#Importing Libraries
from scipy.stats import binom
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
#Forming the binomial distribution table
data = {}
n = 3                                                         #no of experiments
p = 0.5                                                       #Probability of the experiment
k = 0                                                         #Favourable outcome
for k in range(n+1):
    data[k] = float(round(binom.pmf(k=k, n=n, p=p), 3))
    
X = [x for x, y in data.items()]                              #X values 
Y = [y for x, y in data.items()]                              #P(X) values

# %%
#Plotiing the binomial table as barplot
plt.style.use("ggplot") 
plt.bar(X, Y, color="skyblue", width =0.5)
plt.title("Binomial Distribution of a random variable X")
plt.xlabel("X")
plt.ylabel("P(X)")
#Shwoing the value of P(X) on the plot
for i in range(len(X)):
    plt.text(X[i], Y[i]+0.005, str(Y[i]), ha="center", color="red")
plt.tight_layout()
